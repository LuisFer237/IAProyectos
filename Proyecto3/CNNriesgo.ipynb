# %%
import numpy as np
import os
import re
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import keras
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential,Model
from tensorflow.keras.layers import Input
from keras.layers import Dense, Dropout, Flatten
#from keras.layers import Conv2D, MaxPooling2D
#from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    BatchNormalization, SeparableConv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense, Conv2D
)
from keras.layers import LeakyReLU

# %% [markdown]
# # Leer imágenes
#
# Este código está diseñado para recorrer un directorio específico y sus subdirectorios, leer todas las imágenes con extensiones .jpg, .jpeg, .png, .bmp, o .tiff, y almacenar información sobre estas imágenes y los directorios donde se encuentran.

# %%
dirname = os.path.join(os.getcwd(),'C:/Users/luis2/OneDrive - Instituto Tecnológico de Morelia/Documents/Escuela/Semestre 9/IA/IAProyectos/Proyecto3/dataset')
imgpath = dirname + os.sep 

images = []
directories = []
dircount = []
prevRoot=''
cant=0

print("leyendo imagenes de ",imgpath)

for root, dirnames, filenames in os.walk(imgpath):
    for filename in filenames:
        if re.search("\.(jpg|jpeg|png|bmp|tiff)$", filename):
            cant=cant+1
            filepath = os.path.join(root, filename)
            image = plt.imread(filepath)
            if(len(image.shape)==3):
                
                images.append(image)
            b = "Leyendo..." + str(cant)
            print (b, end="\r")
            if prevRoot !=root:
                print(root, cant)
                prevRoot=root
                directories.append(root)
                dircount.append(cant)
                cant=0
                
dircount.append(cant)

dircount = dircount[1:]
dircount[0]=dircount[0]+1
print('Directorios leidos:',len(directories))
print("Imagenes en cada directorio", dircount)
print('suma Total de imagenes en subdirs:',sum(dircount))
# Out:
# <>:14: SyntaxWarning: invalid escape sequence '\.'
# <>:14: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\luis2\AppData\Local\Temp\ipykernel_13716\2019693247.py:14: SyntaxWarning: invalid escape sequence '\.'
#   if re.search("\.(jpg|jpeg|png|bmp|tiff)$", filename):
# leyendo imagenes de  C:/Users/luis2/OneDrive - Instituto Tecnológico de Morelia/Documents/Escuela/Semestre 9/IA/IAProyectos/Proyecto3/dataset\
# C:/Users/luis2/OneDrive - Instituto Tecnológico de Morelia/Documents/Escuela/Semestre 9/IA/IAProyectos/Proyecto3/dataset\812Competizione 1
# C:/Users/luis2/OneDrive - Instituto Tecnológico de Morelia/Documents/Escuela/Semestre 9/IA/IAProyectos/Proyecto3/dataset\G63AMGFacelift 12800
# C:/Users/luis2/OneDrive - Instituto Tecnológico de Morelia/Documents/Escuela/Semestre 9/IA/IAProyectos/Proyecto3/dataset\PorscheGT3RS 12800
# C:/Users/luis2/OneDrive - Instituto Tecnológico de Morelia/Documents/Escuela/Semestre 9/IA/IAProyectos/Proyecto3/dataset\UracanSTO 12800
# C:/Users/luis2/OneDrive - Instituto Tecnológico de Morelia/Documents/Escuela/Semestre 9/IA/IAProyectos/Proyecto3/dataset\Urus 12800
# Directorios leidos: 5
# Imagenes en cada directorio [12801, 12800, 12800, 12800, 12799]
# suma Total de imagenes en subdirs: 64000

# %% [markdown]
# # Generación de Etiquetas
#
# Esta sección del código está asignando una etiqueta numérica a cada imagen basada en el directorio del que proviene. Si un directorio tiene 5 imágenes, todas esas imágenes tendrán la misma etiqueta (por ejemplo, 0), y luego la etiqueta cambiará para el próximo directorio. Esto es útil para clasificar las imágenes según sus directorios de origen.

# %%
labels=[]
indice=0
for cantidad in dircount:
    for i in range(cantidad):
        labels.append(indice)
    indice=indice+1
print("Cantidad etiquetas creadas: ",len(labels))
# Out:
# Cantidad etiquetas creadas:  64000

# %% [markdown]
# Esta sección del código permite identificar y almacenar los nombres de los subdirectorios de manera organizada, lo cual puede ser útil para el análisis posterior o para referenciar los datos procesados.

# %%
sriesgos=[]
indice=0
for directorio in directories:
    name = directorio.split(os.sep)
    print(indice , name[len(name)-1])
    sriesgos.append(name[len(name)-1])
    indice=indice+1
# Out:
# 0 812Competizione
# 1 G63AMGFacelift
# 2 PorscheGT3RS
# 3 UracanSTO
# 4 Urus

# %% [markdown]
# Esta sección del código convierte las listas de etiquetas e imágenes en arreglos de NumPy para facilitar su manipulación. Luego, identifica las clases únicas presentes en las etiquetas y calcula el número total de clases, imprimiendo esta información. Esto es útil para entender la distribución de las clases en el conjunto de datos y preparar los datos para análisis o entrenamiento de modelos.

# %%
y = np.array(labels)
X = np.array(images, dtype=np.uint8) #convierto de lista a numpy

classes = np.unique(y)
nClasses = len(classes)
print('Total number of outputs : ', nClasses)
print('Output classes : ', classes)
# Out:
# Total number of outputs :  5
# Output classes :  [0 1 2 3 4]

# %% [markdown]
# Esta sección del código divide el conjunto de datos en dos partes: datos de entrenamiento (80%) y datos de prueba (20%). Luego, imprime las dimensiones de estos conjuntos de datos. Esta división es crucial en el proceso de entrenamiento y evaluación de modelos de aprendizaje automático, ya que permite evaluar el rendimiento del modelo en datos no vistos durante el entrenamiento.

# %%
train_X,test_X,train_Y,test_Y = train_test_split(X,y,test_size=0.2)
print('Training data shape : ', train_X.shape, train_Y.shape)
print('Testing data shape : ', test_X.shape, test_Y.shape)
# Out:
# Training data shape :  (51200, 21, 28, 3) (51200,)
# Testing data shape :  (12800, 21, 28, 3) (12800,)

# %% [markdown]
# Esta sección del código utiliza Matplotlib para mostrar las primeras imágenes de los conjuntos de datos de entrenamiento y de prueba, junto con sus etiquetas correspondientes.

# %%
plt.figure(figsize=[5,5])

# Display the first image in training data
plt.subplot(121)
plt.imshow(train_X[0,:,:], cmap='gray')
plt.title("Ground Truth : {}".format(train_Y[0]))

# Display the first image in testing data
plt.subplot(122)
plt.imshow(test_X[0,:,:], cmap='gray')
plt.title("Ground Truth : {}".format(test_Y[0]))
# Out:
# Text(0.5, 1.0, 'Ground Truth : 4')

# %% [markdown]
# Esta sección del código convierte los datos de imágenes a tipo de dato float32 y normaliza los valores de píxel para que estén en el rango [0, 1]. Luego, visualiza una imagen del conjunto de datos de prueba. La normalización es crucial para el entrenamiento efectivo de modelos de aprendizaje automático.

# %%
rain_X = train_X.astype('float32')
test_X = test_X.astype('float32')
train_X = train_X/255.
test_X = test_X/255.
plt.imshow(test_X[0,:,:])

# %% [markdown]
# Esta sección del código convierte las etiquetas de clase en formato entero a un formato de codificación one-hot. Esto es importante porque muchos algoritmos de aprendizaje automático, especialmente las redes neuronales, funcionan mejor con etiquetas en formato one-hot. Luego, se imprime una etiqueta antes y después de la conversión para verificar el proceso.

# %%
train_Y_one_hot = to_categorical(train_Y)
test_Y_one_hot = to_categorical(test_Y)
print('Original label:', train_Y[0])
print('After conversion to one-hot:', train_Y_one_hot[0])
# Out:
# Original label: 4
# After conversion to one-hot: [0. 0. 0. 0. 1.]

# %% [markdown]
# Esta sección del código toma el conjunto de datos de entrenamiento y lo divide en dos conjuntos: uno para continuar el entrenamiento y otro para la validación. La validación es una parte crucial del proceso de entrenamiento de modelos de aprendizaje automático porque permite evaluar el rendimiento del modelo en datos no vistos durante el entrenamiento, ayudando a prevenir el sobreajuste.

# %%
#Mezclar todo y crear los grupos de entrenamiento y testing
train_X,valid_X,train_label,valid_label = train_test_split(train_X, train_Y_one_hot, test_size=0.2, random_state=13)

# %% [markdown]
# Esta sección del código es útil para verificar que los conjuntos de datos se han dividido correctamente y que las formas de los datos son las esperadas. Esto asegura que los datos estén listos para ser utilizados en el entrenamiento y validación del modelo.

# %%
print(train_X.shape,valid_X.shape,train_label.shape,valid_label.shape)
# Out:
# (40960, 21, 28, 3) (10240, 21, 28, 3) (40960, 5) (10240, 5)

# %% [markdown]
# Esta sección del código define y configura varios parámetros importantes para el entrenamiento de una red neuronal. Estos parámetros incluyen la tasa de aprendizaje inicial, el número de épocas y el tamaño del lote.

# %%
#declaramos variables con los parámetros de configuración de la red
INIT_LR = 1e-3 # Valor inicial de learning rate. El valor 1e-3 corresponde con 0.001
epochs = 60 # Cantidad de iteraciones completas al conjunto de imagenes de entrenamiento
batch_size = 64 # cantidad de imágenes que se toman a la vez en memoria

# %% [markdown]
# Esta sección del código define un modelo de red neuronal convolucional (CNN) utilizando la API de Keras. La red consta de varias capas, incluyendo capas convolucionales, de activación, de pooling, de normalización (Dropout) y densas (fully connected).

# %%
riesgo_model = Sequential()
riesgo_model.add(Conv2D(32, kernel_size=(3, 3),activation='linear',padding='same',input_shape=(21,28,3)))
riesgo_model.add(LeakyReLU(alpha=0.1))
riesgo_model.add(MaxPooling2D((2, 2),padding='same'))
riesgo_model.add(Dropout(0.5))

# Nueva capa Conv2D con 64 filtros
riesgo_model.add(Conv2D(64, kernel_size=(3, 3),activation='linear',padding='same'))
riesgo_model.add(LeakyReLU(alpha=0.1))
riesgo_model.add(MaxPooling2D((2, 2),padding='same'))
riesgo_model.add(Dropout(0.5))

riesgo_model.add(Flatten())
riesgo_model.add(Dense(32, activation='linear'))
riesgo_model.add(LeakyReLU(alpha=0.1))
riesgo_model.add(Dropout(0.5))
riesgo_model.add(Dense(nClasses, activation='softmax'))
# Out:
# c:\Users\luis2\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\luis2\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(

# %%
riesgo_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 21, 28, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu (LeakyReLU)         │ (None, 21, 28, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 11, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 11, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 11, 14, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_1 (LeakyReLU)       │ (None, 11, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 6, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2688)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │        86,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_2 (LeakyReLU)       │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │           165 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 105,605 (412.52 KB)
#  Trainable params: 105,605 (412.52 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Esta sección del código configura la función de pérdida, el optimizador y las métricas que se utilizarán durante el entrenamiento del modelo. La compilación del modelo es un paso crucial que prepara el modelo para ser entrenado con los datos.

# %%
riesgo_model.compile(loss=keras.losses.categorical_crossentropy, optimizer=tf.keras.optimizers.SGD(learning_rate=INIT_LR, decay=INIT_LR / 100),metrics=['accuracy'])
# Out:
# c:\Users\luis2\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\optimizers\base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(

# %% [markdown]
# Esta sección del código entrena el modelo de red neuronal convolucional utilizando los datos de entrenamiento. Durante el entrenamiento, el modelo se ajusta iterativamente a los datos, actualizando sus parámetros para minimizar la función de pérdida. El conjunto de datos de validación se utiliza para monitorear el rendimiento del modelo y prevenir el sobreajuste.

# %%
riesgo_train = riesgo_model.fit(train_X, train_label, batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(valid_X, valid_label))
# Out:
# Epoch 1/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 20s 29ms/step - accuracy: 0.1970 - loss: 1.6537 - val_accuracy: 0.3444 - val_loss: 1.6012
# Epoch 2/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 19s 29ms/step - accuracy: 0.2235 - loss: 1.6066 - val_accuracy: 0.3238 - val_loss: 1.5949
# Epoch 3/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 18s 27ms/step - accuracy: 0.2521 - loss: 1.5931 - val_accuracy: 0.3706 - val_loss: 1.5842
# Epoch 4/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.2687 - loss: 1.5803 - val_accuracy: 0.3847 - val_loss: 1.5648
# Epoch 5/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 16s 25ms/step - accuracy: 0.2880 - loss: 1.5626 - val_accuracy: 0.4142 - val_loss: 1.5409
# Epoch 6/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 16s 25ms/step - accuracy: 0.3192 - loss: 1.5331 - val_accuracy: 0.4536 - val_loss: 1.5049
# Epoch 7/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 16s 25ms/step - accuracy: 0.3388 - loss: 1.5027 - val_accuracy: 0.4762 - val_loss: 1.4604
# Epoch 8/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 16s 25ms/step - accuracy: 0.3657 - loss: 1.4613 - val_accuracy: 0.4862 - val_loss: 1.4194
# Epoch 9/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 17s 26ms/step - accuracy: 0.3821 - loss: 1.4257 - val_accuracy: 0.4867 - val_loss: 1.3752
# Epoch 10/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 21s 33ms/step - accuracy: 0.4113 - loss: 1.3780 - val_accuracy: 0.5286 - val_loss: 1.3212
# Epoch 11/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 18s 28ms/step - accuracy: 0.4254 - loss: 1.3429 - val_accuracy: 0.5680 - val_loss: 1.2757
# Epoch 12/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.4552 - loss: 1.2982 - val_accuracy: 0.5745 - val_loss: 1.2414
# Epoch 13/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.4726 - loss: 1.2622 - val_accuracy: 0.5972 - val_loss: 1.1953
# Epoch 14/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 18s 28ms/step - accuracy: 0.4863 - loss: 1.2305 - val_accuracy: 0.5993 - val_loss: 1.1553
# Epoch 15/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 17s 26ms/step - accuracy: 0.5055 - loss: 1.1930 - val_accuracy: 0.6046 - val_loss: 1.1218
# Epoch 16/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 16s 25ms/step - accuracy: 0.5235 - loss: 1.1590 - val_accuracy: 0.6237 - val_loss: 1.0907
# Epoch 17/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 16s 25ms/step - accuracy: 0.5322 - loss: 1.1355 - val_accuracy: 0.6575 - val_loss: 1.0513
# Epoch 18/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 16s 25ms/step - accuracy: 0.5512 - loss: 1.0940 - val_accuracy: 0.6629 - val_loss: 1.0162
# Epoch 19/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 16s 25ms/step - accuracy: 0.5654 - loss: 1.0730 - val_accuracy: 0.6764 - val_loss: 0.9824
# Epoch 20/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 16s 25ms/step - accuracy: 0.5723 - loss: 1.0418 - val_accuracy: 0.6952 - val_loss: 0.9519
# Epoch 21/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 16s 25ms/step - accuracy: 0.5941 - loss: 1.0086 - val_accuracy: 0.7027 - val_loss: 0.9189
# Epoch 22/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.5972 - loss: 0.9959 - val_accuracy: 0.7121 - val_loss: 0.8929
# Epoch 23/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.6097 - loss: 0.9683 - val_accuracy: 0.7224 - val_loss: 0.8594
# Epoch 24/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 19s 29ms/step - accuracy: 0.6218 - loss: 0.9459 - val_accuracy: 0.7388 - val_loss: 0.8278
# Epoch 25/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 18s 29ms/step - accuracy: 0.6301 - loss: 0.9251 - val_accuracy: 0.7430 - val_loss: 0.8057
# Epoch 26/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 18s 29ms/step - accuracy: 0.6420 - loss: 0.9050 - val_accuracy: 0.7467 - val_loss: 0.7853
# Epoch 27/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 21s 32ms/step - accuracy: 0.6470 - loss: 0.8843 - val_accuracy: 0.7521 - val_loss: 0.7664
# Epoch 28/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 18s 28ms/step - accuracy: 0.6571 - loss: 0.8703 - val_accuracy: 0.7640 - val_loss: 0.7417
# Epoch 29/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.6685 - loss: 0.8445 - val_accuracy: 0.7665 - val_loss: 0.7242
# Epoch 30/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 17s 26ms/step - accuracy: 0.6707 - loss: 0.8422 - val_accuracy: 0.7730 - val_loss: 0.6964
# Epoch 31/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 17s 26ms/step - accuracy: 0.6762 - loss: 0.8264 - val_accuracy: 0.7824 - val_loss: 0.6700
# Epoch 32/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 17s 26ms/step - accuracy: 0.6826 - loss: 0.8102 - val_accuracy: 0.7839 - val_loss: 0.6692
# Epoch 33/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 17s 26ms/step - accuracy: 0.6938 - loss: 0.7878 - val_accuracy: 0.7896 - val_loss: 0.6499
# Epoch 34/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 17s 26ms/step - accuracy: 0.6931 - loss: 0.7767 - val_accuracy: 0.7950 - val_loss: 0.6310
# Epoch 35/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 16s 25ms/step - accuracy: 0.7008 - loss: 0.7684 - val_accuracy: 0.7994 - val_loss: 0.6174
# Epoch 36/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 17s 26ms/step - accuracy: 0.7063 - loss: 0.7500 - val_accuracy: 0.8052 - val_loss: 0.5965
# Epoch 37/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 17s 26ms/step - accuracy: 0.7147 - loss: 0.7365 - val_accuracy: 0.8049 - val_loss: 0.5954
# Epoch 38/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 17s 26ms/step - accuracy: 0.7172 - loss: 0.7262 - val_accuracy: 0.8104 - val_loss: 0.5716
# Epoch 39/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 17s 26ms/step - accuracy: 0.7234 - loss: 0.7122 - val_accuracy: 0.8180 - val_loss: 0.5573
# Epoch 40/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 17s 26ms/step - accuracy: 0.7275 - loss: 0.7013 - val_accuracy: 0.8254 - val_loss: 0.5408
# Epoch 41/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 17s 26ms/step - accuracy: 0.7342 - loss: 0.6910 - val_accuracy: 0.8302 - val_loss: 0.5303
# Epoch 42/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 17s 26ms/step - accuracy: 0.7342 - loss: 0.6803 - val_accuracy: 0.8285 - val_loss: 0.5290
# Epoch 43/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7379 - loss: 0.6707 - val_accuracy: 0.8377 - val_loss: 0.5111
# Epoch 44/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 18s 27ms/step - accuracy: 0.7462 - loss: 0.6646 - val_accuracy: 0.8428 - val_loss: 0.4956
# Epoch 45/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 18s 28ms/step - accuracy: 0.7493 - loss: 0.6517 - val_accuracy: 0.8452 - val_loss: 0.4867
# Epoch 46/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 22s 35ms/step - accuracy: 0.7479 - loss: 0.6487 - val_accuracy: 0.8489 - val_loss: 0.4762
# Epoch 47/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 18s 29ms/step - accuracy: 0.7513 - loss: 0.6404 - val_accuracy: 0.8540 - val_loss: 0.4623
# Epoch 48/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 17s 26ms/step - accuracy: 0.7574 - loss: 0.6269 - val_accuracy: 0.8544 - val_loss: 0.4598
# Epoch 49/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7627 - loss: 0.6178 - val_accuracy: 0.8620 - val_loss: 0.4459
# Epoch 50/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 17s 26ms/step - accuracy: 0.7682 - loss: 0.6091 - val_accuracy: 0.8645 - val_loss: 0.4348
# Epoch 51/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7713 - loss: 0.6002 - val_accuracy: 0.8667 - val_loss: 0.4296
# Epoch 52/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 17s 26ms/step - accuracy: 0.7712 - loss: 0.5972 - val_accuracy: 0.8675 - val_loss: 0.4262
# Epoch 53/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 17s 26ms/step - accuracy: 0.7782 - loss: 0.5844 - val_accuracy: 0.8715 - val_loss: 0.4121
# Epoch 54/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 17s 26ms/step - accuracy: 0.7798 - loss: 0.5765 - val_accuracy: 0.8811 - val_loss: 0.3979
# Epoch 55/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 17s 26ms/step - accuracy: 0.7823 - loss: 0.5744 - val_accuracy: 0.8823 - val_loss: 0.3941
# Epoch 56/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 17s 26ms/step - accuracy: 0.7854 - loss: 0.5636 - val_accuracy: 0.8844 - val_loss: 0.3905
# Epoch 57/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 17s 26ms/step - accuracy: 0.7841 - loss: 0.5616 - val_accuracy: 0.8897 - val_loss: 0.3770
# Epoch 58/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7897 - loss: 0.5523 - val_accuracy: 0.8897 - val_loss: 0.3755
# Epoch 59/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7909 - loss: 0.5492 - val_accuracy: 0.8930 - val_loss: 0.3633
# Epoch 60/60
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7938 - loss: 0.5426 - val_accuracy: 0.8938 - val_loss: 0.3572

# %%
riesgo_model.save("C:/Users/luis2/OneDrive - Instituto Tecnológico de Morelia/Documents/Escuela/Semestre 9/IA/IAProyectos/Proyecto3model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
test_eval = riesgo_model.evaluate(test_X, test_Y_one_hot, verbose=1)
# Out:
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8994 - loss: 0.3464

# %%
print('Test loss:', test_eval[0])
print('Test accuracy:', test_eval[1])
# Out:
# Test loss: 0.34650424122810364
# Test accuracy: 0.8982031345367432

# %%
accuracy = riesgo_train.history['accuracy']
val_accuracy = riesgo_train.history['val_accuracy']
loss = riesgo_train.history['loss']
val_loss = riesgo_train.history['val_loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
predicted_classes2 = riesgo_model.predict(test_X)
# Out:
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step

# %%
predicted_classes=[]
for predicted_riesgo in predicted_classes2:
    predicted_classes.append(predicted_riesgo.tolist().index(max(predicted_riesgo)))
predicted_classes=np.array(predicted_classes)

# %%
predicted_classes.shape, test_Y.shape
# Out:
# ((12800,), (12800,))

# %%
correct = np.where(predicted_classes==test_Y)[0]
print("Found %d correct labels" % len(correct))
for i, correct in enumerate(correct[0:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(test_X[correct].reshape(21,28,3), cmap='gray', interpolation='none')
    plt.title("{}, {}".format(sriesgos[predicted_classes[correct]],
                                                    sriesgos[test_Y[correct]]))

    plt.tight_layout()
# Out:
# Found 11497 correct labels

# %%
incorrect = np.where(predicted_classes!=test_Y)[0]
print("Found %d incorrect labels" % len(incorrect))
for i, incorrect in enumerate(incorrect[0:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(test_X[incorrect].reshape(21,28,3), cmap='gray', interpolation='none')
    plt.title("{}, {}".format(sriesgos[predicted_classes[incorrect]],
                                                    sriesgos[test_Y[incorrect]]))
    plt.tight_layout()
# Out:
# Found 1303 incorrect labels

# %%
target_names = ["Class {}".format(i) for i in range(nClasses)]
print(classification_report(test_Y, predicted_classes, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.86      0.90      0.88      2565
#      Class 1       0.91      0.98      0.94      2659
#      Class 2       0.83      0.79      0.81      2554
#      Class 3       0.98      0.96      0.97      2507
#      Class 4       0.91      0.86      0.88      2515
#
#     accuracy                           0.90     12800
#    macro avg       0.90      0.90      0.90     12800
# weighted avg       0.90      0.90      0.90     12800

# %%
from skimage.transform import resize

images=[]
# AQUI ESPECIFICAMOS UNAS IMAGENES
filenames = ['C:/Users/luis2/OneDrive - Instituto Tecnológico de Morelia/Documents/Escuela/Semestre 9/IA/IAProyectos/Proyecto3/Images/urus8.jpg']

for filepath in filenames:
    image = plt.imread(filepath,0)
    image_resized = resize(image, (21, 28),anti_aliasing=True,clip=False,preserve_range=True)
    images.append(image_resized)

X = np.array(images, dtype=np.uint8) #convierto de lista a numpy
test_X = X.astype('float32')
test_X = test_X / 255.

predicted_classes = riesgo_model.predict(test_X)

for i, img_tagged in enumerate(predicted_classes):
    print(filenames[i], sriesgos[img_tagged.tolist().index(max(img_tagged))])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# C:/Users/luis2/OneDrive - Instituto Tecnológico de Morelia/Documents/Escuela/Semestre 9/IA/IAProyectos/Proyecto3/Images/urus8.jpg PorscheGT3RS
